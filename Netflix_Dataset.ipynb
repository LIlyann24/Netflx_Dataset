# %% [markdown]
# # Import Netflix Movies and TV Series dataset

# %%
import pandas as pd
data = pd.read_excel('D:\\Python\\Side Project\\Netflix Dataset\\8. Netflix Dataset.xlsx')
data
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                     0.03
# 1         s2    Movie                                 0.304861
# 2         s3    Movie                                 0.999306
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %% [markdown]
# # Clean Data: Find the duplicaed data and remove it

# %%
data[data.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
##Remove duplicates
data.drop_duplicates(inplace = True)
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description]
# Index: []

# %% [markdown]
# # isin(): find the specific data in the series.

# %%
##isin()函式找出示否存在該資料
data[data['Title'].isin(['House of Cards'])]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %% [markdown]
# # Prepare Data1: .to_datetime: convert the date to date format.

# %%
data.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
data['Date_N'] = pd.to_datetime(data['Release_Date'])
data
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                     0.03
# 1         s2    Movie                                 0.304861
# 2         s3    Movie                                 0.999306
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
data.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date            object
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# Date_N          datetime64[ns]
# dtype: object

# %% [markdown]
# # Visualization1: counts of "Year" in histogram with the .plot function

# %%
data['Date_N'].dt.year.value_counts().plot(kind = 'bar')
# Out:
# <Axes: >

# %% [markdown]
# # Visualization2: counts of  each category in histogram with the .plot function

# %%
data.groupby('Category').Category.count().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Category'>

# %% [markdown]
# # Prepare Data2: Create a new column only consider "year"

# %%
data['Year'] = data['Date_N'].dt.year
data
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                     0.03
# 1         s2    Movie                                 0.304861
# 2         s3    Movie                                 0.999306
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %% [markdown]
# # Q1: Show all the movies that were released in year 2000.

# %%
data[(data['Category'] == 'Movie') & (data['Year'] == 2020)]
# Out:
#      Show_Id Category                                    Title  \
# 4         s5    Movie                                       21
# 6         s7    Movie                                      122
# 14       s15    Movie                                     3022
# 27       s28    Movie                                   #Alive
# 28       s29    Movie            #AnneFrank - Parallel Stories
# ...      ...      ...                                      ...
# 7762   s7761    Movie                                Zaki Chan
# 7783   s7782    Movie                                     Zoom
# 7784   s7783    Movie                                     Zozo
# 7786   s7785    Movie                        Zulu Man in Japan
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                          Director  \
# 4                  Robert Luketic
# 6                 Yasir Al Yasiri
# 14                     John Suits
# 27                         Cho Il
# ...

# %% [markdown]
# # Q2: Show only the titles on all TV shows that were released in India only.

# %%
data[(data['Category'] == 'TV Show') & (data['Country'] == 'India')] ['Title']
# Out:
# 86            21 Sarfarosh: Saragarhi 1897
# 132                              7 (Seven)
# 340                           Agent Raghav
# 364                           Akbar Birbal
# 533                    Anjaan: Rural Myths
#                        ...
# 6249                  The Creative Indians
# 6400    The Golden Years with Javed Akhtar
# 6469                The House That Made Me
# 7294                            Typewriter
# 7705                       Yeh Meri Family
# Name: Title, Length: 71, dtype: object

# %% [markdown]
# # Q3: Snow top 10 directors, who gave the highest of TV shows & moves to Netflix.

# %%
data['Director'].value_counts().head(10)
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Youssef Chahine           12
# Martin Scorsese           12
# Steven Spielberg          10
# David Dhawan               9
# Hakan Algül                8
# Name: Director, dtype: int64

# %% [markdown]
# # Q4: Show all the records of comedy movies or only released in United Kingdom.

# %%
mask1 = (data['Category'] == 'Movie') & (data['Type'] == 'Comedies')
data[mask1].head(2)
# Out:
#    Show_Id Category         Title          Director  \
# 33     s34    Movie  #realityhigh  Fernando Lebrija
# 72     s73    Movie      17 Again       Burr Steers
#
#                                                  Cast        Country  \
# 33  Nesta Cooper, Kate Walsh, John Michael Higgins...  United States
# 72  Zac Efron, Leslie Mann, Matthew Perry, Thomas ...  United States
#
#          Release_Date Rating Duration      Type  \
# 33  September 8, 2017  TV-14   99 min  Comedies
# 72    January 1, 2021  PG-13  102 min  Comedies
#
#                                           Description     Date_N    Year
# 33  When nerdy high schooler Dani finally attracts... 2017-09-08  2017.0
# 72  Nearing a midlife crisis, thirty-something Mik... 2021-01-01  2021.0

# %%
mask2 = data['Country'] == 'United Kingdom'
data[mask2].head(2)
# Out:
#    Show_Id Category        Title Director  \
# 19     s20    Movie           89      NaN
# 58     s59  TV Show  100% Hotter      NaN
#
#                                                  Cast         Country  \
# 19                 Lee Dixon, Ian Wright, Paul Merson  United Kingdom
# 58  Daniel Palmer, Melissa Sophia, Karen Williams,...  United Kingdom
#
#         Release_Date Rating  Duration  \
# 19      May 16, 2018  TV-PG    87 min
# 58  November 1, 2019  TV-14  1 Season
#
#                                                  Type  \
# 19                                      Sports Movies
# 58  British TV Shows, International TV Shows, Real...
#
#                                           Description     Date_N    Year
# 19  Mixing old footage with interviews, this is th... 2018-05-16  2018.0
# 58  A stylist, a hair designer and a makeup artist... 2019-11-01  2019.0

# %%
data[mask1 | mask2].head(5)
# Out:
#    Show_Id Category                Title          Director  \
# 19     s20    Movie                   89               NaN
# 33     s34    Movie         #realityhigh  Fernando Lebrija
# 58     s59  TV Show          100% Hotter               NaN
# 72     s73    Movie             17 Again       Burr Steers
# 82     s83    Movie  2036 Origin Unknown     Hasraf Dulull
#
#                                                  Cast         Country  \
# 19                 Lee Dixon, Ian Wright, Paul Merson  United Kingdom
# 33  Nesta Cooper, Kate Walsh, John Michael Higgins...   United States
# 58  Daniel Palmer, Melissa Sophia, Karen Williams,...  United Kingdom
# 72  Zac Efron, Leslie Mann, Matthew Perry, Thomas ...   United States
# 82  Katee Sackhoff, Ray Fearon, Julie Cox, Steven ...  United Kingdom
#
#          Release_Date Rating  Duration  \
# 19       May 16, 2018  TV-PG    87 min
# 33  September 8, 2017  TV-14    99 min
# 58   November 1, 2019  TV-14  1 Season
# ...

# %% [markdown]
# # Q5: Find how many movies or TV shows that Tom Cruise was casted.

# %%
##Notice there is NaN in the "Cast" column.
data[data['Cast'].str.contains('Tom Cruise')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[365], line 2
#       1 ##Notice there is NaN in the "Cast" column.
# ----> 2 data[data['Cast'].str.contains('Tom Cruise')]
#
# File ~\anaconda3\envs\Demo1\lib\site-packages\pandas\core\frame.py:3797, in DataFrame.__getitem__(self, key)
#    3794     return self.where(key)
#    3796 # Do we have a (boolean) 1d indexer?
# -> 3797 if com.is_bool_indexer(key):
#    3798     return self._getitem_bool_array(key)
#    3800 # We are left with two options: a single key, and a collection of keys,
#    3801 # We interpret tuples as collections only for non-MultiIndex
#
# File ~\anaconda3\envs\Demo1\lib\site-packages\pandas\core\common.py:135, in is_bool_indexer(key)
#     131     na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
# ...

# %%
##Create a new dataframe "data_new" to present the result without changing the original dataframe.
##Drops the rolls that contains all or any missing values
data_new = data.dropna()
data_new.head()
# Out:
#   Show_Id Category     Title           Director  \
# 1      s2    Movie  0.304861  Jorge Michel Grau
# 2      s3    Movie  0.999306       Gilbert Chan
# 3      s4    Movie         9        Shane Acker
# 4      s5    Movie        21     Robert Luketic
# 5      s6  TV Show        46        Serdar Akar
#
#                                                 Cast        Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 5  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...         Turkey
#
#         Release_Date Rating  Duration  \
# 1  December 23, 2016  TV-MA    93 min
# 2  December 20, 2018      R    78 min
# 3  November 16, 2017  PG-13    80 min
# 4    January 1, 2020  PG-13   123 min
# 5       July 1, 2017  TV-MA  1 Season
#
# ...

# %%
data_new[data_new['Cast'].str.contains('Tom Cruise')]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#          Release_Date Rating Duration                        Type  \
# 3860  January 1, 2020      R  189 min  Dramas, Independent Movies
# 5071     July 1, 2019      R  134 min      Classic Movies, Dramas
#
#                                             Description     Date_N    Year
# 3860  Through chance, human action, past history and... 2020-01-01  2020.0
# 5071  A fast-talking yuppie is forced to slow down w... 2019-07-01  2019.0

# %% [markdown]
# # Q6: Find the different ratings defined by Netflix.

# %%
##.nunique(): Count number of distinct elements in specified axis.
data['Rating'].nunique()
# Out:
# 14

# %%
##.unique(): show the values
data['Rating'].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# # Q6-1: How many movies got the "TV-14" rating in Canada?

# %%
data[(data['Category'] == 'Movie') & (data['Rating'] == 'TV-14') & (data['Country'] == 'Canada')]
# Out:
#      Show_Id Category                                        Title  \
# 30       s31    Movie                             #cats_the_mewvie
# 34       s35    Movie                                        #Roxy
# 608     s609    Movie                               At First Light
# 1506   s1507    Movie                   Counterfeiting in Suburbia
# 3713   s3714    Movie                            Long Time Running
# 3956   s3957    Movie  Martin Matte: La vie, la mort...eh la la..!
# 5336   s5336    Movie                   Sadie's Last Days on Earth
# 5393   s5393    Movie                                   Sardaar ji
# 6062   s6062    Movie                  The Accountant of Auschwitz
# 7025   s7024    Movie                         The Wrong Babysitter
# 7041   s7040    Movie               There's Something in the Water
#
#                                     Director  \
# 30                          Michael Margolis
# 34                           Michael Kennedy
# ...

# %%
data[(data['Category'] == 'Movie') & (data['Rating'] == 'TV-14') & (data['Country'] == 'Canada')].shape
# Out:
# (11, 13)

# %% [markdown]
# # Q6-2: How many TV shows got "R" rating after year 2018?

# %%
data[(data['Category'] == 'TV Show') & (data['Rating'] == 'R') & (data['Year'] >= 2018)]
# Out:
#      Show_Id Category                                Title           Director  \
# 6437   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    Cast Country  \
# 6437  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN
#
#         Release_Date Rating  Duration      Type  \
# 6437  April 25, 2019      R  1 Season  TV Shows
#
#                                             Description     Date_N    Year
# 6437  Trapped at a stagecoach stop as a storm rages ... 2019-04-25  2019.0

# %% [markdown]
# # Q7: Find the max and min duration of the movie/shows in Netflix

# %%
##=data['Duration'].unique()
data.Duration.unique()
# Out:
# array(['4 Seasons', '93 min', '78 min', '80 min', '123 min', '1 Season',
#        '95 min', '119 min', '118 min', '143 min', '103 min', '89 min',
#        '91 min', '149 min', '144 min', '124 min', '87 min', '110 min',
#        '128 min', '117 min', '100 min', '2 Seasons', '84 min', '99 min',
#        '90 min', '102 min', '104 min', '105 min', '56 min', '125 min',
#        '81 min', '97 min', '106 min', '107 min', '109 min', '44 min',
#        '75 min', '101 min', '3 Seasons', '37 min', '113 min', '114 min',
#        '130 min', '94 min', '140 min', '135 min', '82 min', '70 min',
#        '121 min', '92 min', '164 min', '53 min', '83 min', '116 min',
#        '86 min', '120 min', '96 min', '126 min', '129 min', '77 min',
#        '137 min', '148 min', '28 min', '122 min', '176 min', '85 min',
#        '22 min', '68 min', '111 min', '29 min', '142 min', '168 min',
#        '21 min', '59 min', '20 min', '98 min', '108 min', '76 min',
# ...

# %%
data.Duration.dtypes
# Out:
# dtype('O')

# %%
##str.split(): https://pandas.pydata.org/docs/reference/api/pandas.Series.str.split.html
data[['Miniutes','Unit']] = data['Duration'].str.split(' ', expand=True)
data.head(2)
# Out:
#   Show_Id Category     Title           Director  \
# 0      s1  TV Show      0.03                NaN
# 1      s2    Movie  0.304861  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     Date_N    Year  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0
#
#   Miniutes     Unit
# 0        4  Seasons
# 1       93      min

# %%
data.Miniutes.max()
# Out:
# '99'

# %%
data.Miniutes.min()
# Out:
# '1'

# %% [markdown]
# # Q8: Which country has the highest numbers of TV shows?

# %%
## Create a new data frame "data_tvshow"
data_tvshow = data[data['Category'] == 'TV Show']
data_tvshow.head(2)
# Out:
#   Show_Id Category Title     Director  \
# 0      s1  TV Show  0.03          NaN
# 5      s6  TV Show    46  Serdar Akar
#
#                                                 Cast Country     Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
# 5  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...  Turkey     July 1, 2017
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 5  TV-MA   1 Season    International TV Shows, TV Dramas, TV Mysteries
#
#                                          Description     Date_N    Year  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 5  A genetics professor experiments with a treatm... 2017-07-01  2017.0
#
#   Miniutes     Unit
# 0        4  Seasons
# 5        1   Season

# %%
data_tvshow.Country.value_counts().head(1)
# Out:
# United States    705
# Name: Country, dtype: int64

# %%
## Sort the resut by year-ASC.
data.sort_values(by='Year', ascending=False).head(2)
# Out:
#      Show_Id Category            Title                 Director  \
# 5564   s5564    Movie  Sherlock Holmes              Guy Ritchie
# 5919   s5919    Movie        Surf's Up  Ash Brannon, Chris Buck
#
#                                                    Cast  \
# 5564  Robert Downey Jr., Jude Law, Rachel McAdams, M...
# 5919  Shia LaBeouf, Jeff Bridges, Zooey Deschanel, J...
#
#                                                 Country     Release_Date  \
# 5564  United States, Germany, United Kingdom, Australia  January 1, 2021
# 5919                                      United States  January 1, 2021
#
#      Rating Duration                                               Type  \
# 5564  PG-13  128 min                       Action & Adventure, Comedies
# 5919     PG   86 min  Children & Family Movies, Comedies, Sports Movies
#
#                                             Description     Date_N    Year  \
# 5564  The game is afoot for an eccentric detective w... 2021-01-01  2021.0
# ...

# %% [markdown]
# # Q9: Find all the instances where: (1)"Category" is "Movie" and "Type" is "Dramas" or (2)"Category" is "TV Show" and "Type" is "Kids' TV"

# %%
mask3 = (data['Category']=='Movie') & (data['Type']=='Dramas')
data[mask3].head(2)
# Out:
#   Show_Id Category Title        Director  \
# 4      s5    Movie    21  Robert Luketic
# 7      s8    Movie   187  Kevin Reynolds
#
#                                                 Cast        Country  \
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 7  Samuel L. Jackson, John Heard, Kelly Rowan, Cl...  United States
#
#        Release_Date Rating Duration    Type  \
# 4   January 1, 2020  PG-13  123 min  Dramas
# 7  November 1, 2019      R  119 min  Dramas
#
#                                          Description     Date_N    Year  \
# 4  A brilliant group of students become card-coun... 2020-01-01  2020.0
# 7  After one of his high school students attacks ... 2019-11-01  2019.0
#
#   Miniutes Unit
# 4      123  min
# 7      119  min

# %%
mask4 = (data["Category"]=="TV Show") & (data["Type"]=="Kids' TV")
data[mask4].head(2)
# Out:
#     Show_Id Category         Title     Director  \
# 111    s112  TV Show       44 Cats          NaN
# 276    s277  TV Show  Abby Hatcher  Kyran Kelly
#
#                                                   Cast                Country  \
# 111  Sarah Natochenny, Suzy Myers, Simona Berman, E...                  Italy
# 276  Macy Drouin, Wyatt White, Paul Sun-Hyung Lee, ...  United States, Canada
#
#         Release_Date Rating   Duration      Type  \
# 111  October 1, 2020  TV-Y7  2 Seasons  Kids' TV
# 276     July 1, 2020   TV-Y   1 Season  Kids' TV
#
#                                            Description     Date_N    Year  \
# 111  Paw-esome tales abound when singing furry frie... 2020-10-01  2020.0
# 276  A big-hearted girl helps her Fuzzly friends wh... 2020-07-01  2020.0
#
#     Miniutes     Unit
# 111        2  Seasons
# 276        1   Season

# %%
data[mask3 | mask4].head()
# Out:
#     Show_Id Category                       Title        Director  \
# 4        s5    Movie                          21  Robert Luketic
# 7        s8    Movie                         187  Kevin Reynolds
# 111    s112  TV Show                     44 Cats             NaN
# 170    s171    Movie                A Family Man   Mark Williams
# 232    s233    Movie  A Stoning in Fulham County   Larry Elikann
#
#                                                   Cast                Country  \
# 4    Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...          United States
# 7    Samuel L. Jackson, John Heard, Kelly Rowan, Cl...          United States
# 111  Sarah Natochenny, Suzy Myers, Simona Berman, E...                  Italy
# 170  Gerard Butler, Gretchen Mol, Alison Brie, Will...  Canada, United States
# 232  Ken Olin, Jill Eikenberry, Maureen Mueller, Gr...          United States
#
#           Release_Date Rating   Duration      Type  \
# ...
